# %%
import sys  
sys.path.insert(1, "..")
from hfsp_scripts import hfsp_functions as hfsp
import numpy as np
import matplotlib.pyplot as plt 
from scipy import stats
import networkx as nx
import pandas as pd
import altair as alt

# %%
T1 = hfsp.create_tissue("../inputs/sam.csv", True) # Get your CSV's with correct path here.
hfsp.update_rule_nodes(T1, 0, 0, 0.03 , 0 ,[3,3])
hfsp.update_rule_edges(T1, 0.3,1)
hfsp.update_rule_nodes(T1, 0, 0, 0.03 , 0 , [3,3])
hfsp.update_rule_edges(T1, 0.3, 1)
hfsp.update_rule_nodes(T1, 0, 0, 0.03 , 0 ,[3,3])
hfsp.update_rule_edges(T1, 0.3,1)
hfsp.update_rule_nodes(T1, 0, 0, 0.03 , 0 ,[3,3])
hfsp.update_rule_edges(T1, 0.3,1)
hfsp.update_rule_nodes(T1, 0, 0, 0.03 , 0 ,[3,3])
hfsp.update_rule_edges(T1, 0.3,1)
hfsp.update_rule_nodes(T1, 0, 0, 0.03 , 0 ,[3,3])
hfsp.update_rule_edges(T1, 0.3,1)
hfsp.update_rule_nodes(T1, 0, 0, 0.03 , 0 ,[3,3])
hfsp.update_rule_edges(T1, 0.3,1)
hfsp.plt_tissue(T1, edge_state = True, save_with_name = None)

# %%
labels = ['t_initial', 't1', 't1.5', 't2', 't2.5', 't3', 't3.5', 't4']
x_axis = np.arange(len(labels))
y = [0, 7, 14, 22, 40, 65, 87, 95]
plt.bar(x_axis, y ,  width=0.5, color = 'black')
plt.ylabel("Percentage of open PD's")
plt.title('coupled edge-node dynamics')
plt.xticks(x_axis, labels)
plt.savefig("edgedyn_barplot")
plt.show()
