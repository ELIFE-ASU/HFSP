# %%
import sys  
sys.path.insert(1, "..")
from hfsp_scripts import hfsp_functions as hfsp
import numpy as np
import matplotlib.pyplot as plt 
from scipy import stats
import networkx as nx
import pandas as pd
import altair as alt

# %%
Net_0 = hfsp.create_tissue("../inputs/sam.csv", True)

# %%
def plot_degree_dist(g):
    degrees = [g.degree(n) for n in g.nodes()]
    plt.hist(degrees)
    plt.show()

# %%
p1 = ggplot(df1) + geom_bar(aes(x='a')) +\
labs(title='Assembly Index distribution (abm_m0)') +\
xlab('Assembly Index (a)') +\
ylab('Count') +\
theme(text=element_text(family='Consolas',
                        size=10),
      axis_title=element_text(face='bold'),
      axis_text=element_text(face='italic'),
      plot_title=element_text(face='bold',
                              size=12)) +\
scale_x_continuous(breaks=range(0, 20, 1))

# %%
while True:  
    s=[]
    while len(s)<282:
        nextval = int(nx.utils.powerlaw_sequence(, 4)[0]) #282 nodes, power-law exponent 1.1
        if nextval!=0:
            s.append(nextval)
    if sum(s)%2 == 0:
        break
G = nx.configuration_model(s)
G=nx.Graph(G) # remove parallel edges
G.remove_edges_from(nx.selfloop_edges(G))

#draw and show graph
plt.figure(figsize = (20,20))
pos = nx.kamada_kawai_layout(G)
nx.draw_networkx(G, pos)

len(list(G.edges()))
# Out:
# 187

# %%
plot_degree_dist(G)

# %%
H = nx.barabasi_albert_graph(n = 282, m = 2, seed=2)

# %%
plt.figure(figsize = (20,20))
pos = nx.kamada_kawai_layout(H)
nx.draw_networkx(H, pos)
len(list(H.edges()))
# Out:
# 560

# %%
plot_degree_dist(H)

# %%
len(list(Net_0.edges()))
# Out:
# 791
