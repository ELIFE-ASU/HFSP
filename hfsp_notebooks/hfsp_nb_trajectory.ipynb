# %%
import sys  
sys.path.insert(1, "..")
from hfsp_scripts import hfsp_functions as hfsp
import numpy as np
import matplotlib.pyplot as plt 
from scipy import stats
import networkx as nx
import pandas as pd
import collections
import itertools
import altair as alt

# %%
T = hfsp.create_tissue("../inputs/sam.csv", True)
g = T

temp_sch_4wC = np.array([672])
temp_sch_4wCW = np.array([20,4,20,4,20,4,20,4,20,4,20,4,20,4,20,4,20,4,20,4,20,4,20,4,20,4,20,4,20,4,20,4,20,4,
                          20,4,20,4,20,4,20,4,20,4,20,4,20,4,20,4,20,4,20,4,20,4,20,4,20,4,20,4,20,4,20,4,12])

p_decay = 0
p_cold = 0.0003
p_warm = 0.03
p_edge = 0

# %%
df1 = hfsp.ensemble(g, temp_sch_4wCW, p_decay, p_cold, p_warm, p_edge, rule_code_node = [0,0.3], rule_code_edge = None, ensemble_size = 10 , jump_state = 'default')

# %%
hfsp.update_spontaneous(g, jump_state = "default")
df2 = hfsp.ensemble(g, temp_sch_4wCW, p_decay, p_cold, p_warm, p_edge, rule_code_node = [0,0.35], rule_code_edge = None, ensemble_size = 10 , jump_state = 'default')

# %%
hfsp.update_spontaneous(g, jump_state = "default")
df3 = hfsp.ensemble(g, temp_sch_4wCW, p_decay, p_cold, p_warm, p_edge, rule_code_node = [0,0.45], rule_code_edge = None, ensemble_size = 10 , jump_state = 'default')

# %%
hfsp.update_spontaneous(g, jump_state = "default")
df4 = hfsp.ensemble(g, temp_sch_4wCW, p_decay, p_cold, p_warm, p_edge, rule_code_node = [0,0.6], rule_code_edge = None, ensemble_size = 10 , jump_state = 'default')

# %%
hfsp.update_spontaneous(g, jump_state = "default")
df5 = hfsp.ensemble(g, temp_sch_4wCW, p_decay, p_cold, p_warm, p_edge, rule_code_node = [0,0.8], rule_code_edge = None, ensemble_size = 10 , jump_state = 'default')

# %%
hfsp.percentGA_plt(df1, color = 'red') +\
hfsp.percentGA_plt(df2, color = 'red') +\
hfsp.percentGA_plt(df3, color = 'purple') +\
hfsp.percentGA_plt(df4, color = 'purple') +\
hfsp.percentGA_plt(df5, color = 'blue')
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\altair\utils\core.py:283: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.LayerChart(...)
