# %%
import numpy as np
import matplotlib.pyplot as plt 
from IPython.display import Math, Latex # for latex equations
from IPython.core.display import Image # for displaying images
from scipy import stats
from scipy import optimize
import networkx as nx
import pandas as pd
from pyvis.network import Network
import collections
import itertools
import altair as alt
import hfsp_functions as hfsp

# %%
T1 = hfsp.create_tissue("../data/exp_raw/sam.csv", True) # Get your CSV's with correct path here.
hfsp.update_rule_nodes(T1, 0, 0, 0.07,0 ,1)
hfsp.update_rule_edges(T1, 0.3,1)
hfsp.update_rule_nodes(T1, 0, 0, 0.07,0 ,1)
hfsp.update_rule_edges(T1, 0.3,1)
hfsp.update_rule_nodes(T1, 0, 0, 0.07,0 ,1)
hfsp.update_rule_edges(T1, 0.3,1)
hfsp.update_rule_nodes(T1, 0, 0, 0.07,0 ,1)
hfsp.update_rule_edges(T1, 0.3,1)
hfsp.update_rule_nodes(T1, 0, 0, 0.07,0 ,1)
hfsp.update_rule_edges(T1, 0.3,1)
hfsp.update_rule_nodes(T1, 0, 0, 0.07,0 ,1)
hfsp.update_rule_edges(T1, 0.3,1)
hfsp.update_rule_nodes(T1, 0, 0, 0.07,0 ,1)
hfsp.update_rule_edges(T1, 0.6,1)
# hfsp.update_rule_nodes(T1, 0, 0, 0.05,0 ,1)
# hfsp.update_rule_edges(T1, 0.2,1)
# hfsp.update_rule_nodes(T1, 0, 0, 0.05,0 ,1)
# hfsp.update_rule_edges(T1, 0.2,1)
hfsp.plt_tissue(T1, edge_state = True, save_with_name = "edgedyn_cpl_t8")

# %%
labels = ['t_initial', 't1', 't1.5', 't2', 't2.5', 't3', 't3.5', 't4']
x_axis = np.arange(len(labels))
y = [0, 7, 14, 22, 40, 65, 87, 95]
plt.bar(x_axis, y ,  width=0.5, color = 'black')
plt.ylabel("Percentage of open PD's")
plt.title('coupled edge-node dynamics')
plt.xticks(x_axis, labels)

# Add legend

# plt.legend(loc='upper left')

# Display
plt.savefig("edgedyn_barplot")
plt.show()
